# %%
import pandas as pd


data = pd.read_csv('Combined_data.csv', sep=';')
data.columns
# Out:
# Index(['Unnamed: 0', 'Sr. no.', 'start_date_local', 'type', 'distance',
#        'moving_time', 'elapsed_time', 'total_elevation_gain', 'start_latlng',
#        'end_latlng', 'sport_type', 'start_date', 'timezone',
#        'achievement_count', 'kudos_count', 'comment_count', 'athlete_count',
#        'photo_count', 'average_speed', 'max_speed', 'lat', 'lng',
#        'MinTemperature', 'MaxTemperature', 'TotalPrecipitation',
#        'MaxWindSpeed', 'SolarRadiation', 'SunshineDuration', 'RainSum',
#        'SnowFall'],
#       dtype='object')

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd



dataset = pd.DataFrame(data)  # Replace with actual table reference
dataset.drop(columns=['Unnamed: 0', 'Sr. no.', 'start_date_local', 'type','start_latlng',
       'end_latlng', 'sport_type', 'start_date', 'timezone', 'photo_count','lat', 'lng',
      'TotalPrecipitation','SnowFall' ], inplace=True)
dataset.replace({',':'.'}, regex=True, inplace=True)

correlation_matrix = dataset.corr()

# Plot heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f")
plt.show()
